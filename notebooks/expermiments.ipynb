# %% [markdown]
# # Hier probiere ich ganz lustig und wild rum

# %% [markdown]
# Speziell versuche ich einfach mal ohne Vorahnung nur mit meinem mathematischen Verständnis ein Konzept eines Neuronalen Netzes zu entwerfen. Einfach weil ich vorallem diesen explorativen Teil nicht verpassen will. Hierbei orientiere ich mich vorallem an [forward-pass-andbackpropagation.pdf](../docs/math-notes/forward-pass-and-backpropagation-example.pdf) wo ich einfach mal händich einen forward pass und eine backpropagation durch gerechnet habe.

# %% [markdown]
# Installiere dependencies gerne über:
